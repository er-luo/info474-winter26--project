# %%
import pandas as pd
import os

# %% [markdown]
# Maust uw data

# %%
folder  = 'data/Maust_et_al_data'

weather_data = pd.read_csv(os.path.join(folder, 'weather_data.csv'))
weather_data_og = weather_data.copy()   
stages_data = pd.read_csv(os.path.join(folder, 'stages_data.csv'))
blossom_data = pd.read_csv(os.path.join(folder, 'blossom_dates.csv'))
print("Loaded uw data files successfully.")

uw_data = []
uw_data.append(weather_data)
uw_data.append(stages_data)
uw_data.append(blossom_data)
print("uw files appended to list successfully.")  

sdot_data = pd.read_csv('data/SDOT_Trees_data.csv', low_memory=False)
print("Loaded SDOT tree data successfully.")
# Out:
# Loaded uw data files successfully.
# uw files appended to list successfully.
# Loaded SDOT tree data successfully.

# %%
for dfs in uw_data:
    print("\n")
    print(dfs.head())
# Out:
#      STATIONID                        NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00024281  SEATTLE PORTAGE BAY, WA US     47.65     -122.3        5.8
# 1  USW00024281  SEATTLE PORTAGE BAY, WA US     47.65     -122.3        5.8
# 2  USW00024281  SEATTLE PORTAGE BAY, WA US     47.65     -122.3        5.8
# 3  USW00024281  SEATTLE PORTAGE BAY, WA US     47.65     -122.3        5.8
# 4  USW00024281  SEATTLE PORTAGE BAY, WA US     47.65     -122.3        5.8
#
#      DATE  TMAX  TMIN Unnamed: 8 Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0  1/1/63  11.1   8.9        NaN        NaN          NaN          NaN
# 1  1/2/63  11.1  10.0        NaN        NaN          NaN          NaN
# 2  1/3/63  11.1   6.7        NaN        NaN          NaN          NaN
# 3  1/4/63   7.8   5.0        NaN        NaN          NaN          NaN
# 4  1/5/63   5.6   3.3        NaN        NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
#
#    YEAR                                TRANSITION TRANSITIONDATE
# 0  2018               Red Bud-Green Color in Buds            NaN
# 1  2018       Green Color in Buds-Florets Visible          7-Feb
# 2  2018      Florets Visible-Extension of Florets            NaN
# 3  2018  Extension of Florets-Peduncle Elongation            NaN
# 4  2018           Peduncle Elongation-Puffy White         12-Mar
#
#
#    YEAR                                              PLANT  BLOOMDAY  \
# 0  1966  Somei-yoshino (Prunus x yedoensis), Liberal Ar...      97.0
# 1  1967  Somei-yoshino (Prunus x yedoensis), Liberal Ar...      64.0
# 2  1968  Somei-yoshino (Prunus x yedoensis), Liberal Ar...       NaN
# 3  1969  Somei-yoshino (Prunus x yedoensis), Liberal Ar...     107.0
# 4  1970  Somei-yoshino (Prunus x yedoensis), Liberal Ar...       NaN
#
#                METHOD
# 0  Newspaper archives
# 1  Newspaper archives
# 2  Newspaper archives
# 3  Newspaper archives
# 4  Newspaper archives

# %%
def clean(df, columns_to_keep, drop_dupes_column, drop_na):    
    df.columns = df.columns.str.lower()
    df = df[columns_to_keep]
    og = df.copy()
    if drop_na:
        df = df.dropna(subset=drop_na)
    if drop_dupes_column is not None:
        df = df.drop_duplicates(subset=[drop_dupes_column])
    removed = len(og) - len(df)
    print(f"{removed} rows dropped")
    return df

# %%
weather_data = clean(weather_data, ['date', 'tmax', 'tmin'], 'date', False)
stages_data = clean(stages_data, stages_data.columns.str.lower(), None, False)
blossom_data = clean(blossom_data, blossom_data.columns.str.lower(), None, False)

folder = 'data/clean'
weather_data.to_csv(os.path.join(folder, 'output_file.csv'), index=False)
stages_data.to_csv(os.path.join(folder, 'stages_output_file.csv'), index=False)
blossom_data.to_csv(os.path.join(folder, 'blossom_output_file.csv'), index=False)
print("Cleaned data files saved successfully.")
# Out:
# 4079 rows dropped
# 0 rows dropped
# 0 rows dropped
# Cleaned data files saved successfully.

# %% [markdown]
# SDOT data

# %%
sdot_data.columns
# Out:
# Index(['OBJECTID', 'COMPKEY', 'UNITID', 'UNITDESC', 'CONDITION',
#        'CONDITION_ASSESSMENT_DATE', 'CURRENT_STATUS', 'PRIMARYDISTRICTCD',
#        'SECONDARYDISTRICTCD', 'OVERRIDEYN', 'COMPTYPE', 'SEGKEY', 'UNITTYPE',
#        'OWNERSHIP', 'CURRENT_STATUS_DATE', 'LAST_VERIFY_DATE', 'PLANTED_DATE',
#        'BOTANICAL_NAME', 'SCIENTIFIC_NAME', 'HERITAGE', 'EXCEPTIONAL',
#        'CODEREQ', 'GSI', 'GREEN_FACTOR', 'WIRES', 'CABLED',
#        'CLEARANCE_PROBLEM', 'SPACETYPE', 'SITETYPE', 'GROWSPACE', 'DIAM',
#        'CONDITION_RATING', 'FUNDING_SOURCE', 'WATER_THROUGH_YR1',
#        'WATER_THROUGH_YR2', 'WATER_THROUGH_YR3', 'OWNERDIAM', 'EXPDATE',
#        'COMMON_NAME', 'TREEHEIGHT', 'ASBUILTPLANNO', 'LANDSCAPEAREAASSOC',
#        'COMMENTS', 'OVERRIDECOMMENT', 'SHAPE_LNG', 'SHAPE_LAT',
#        'IRRIGATESYSYN', 'ASSETGROUPID', 'ASSETGROUPDESC', 'MODDATE',
#        'TOTAL_RANK', 'TOTAL_COUNT', 'GENUS', 'UFMAINTMGMTUNIT', 'x', 'y'],
#       dtype='object')
